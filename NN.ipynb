# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\My_programs_2\Anaconda\lib\site-packages\keras\__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ModuleNotFoundError: No module named 'tensorflow'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-d80261375fb6> in <module>
#       1 import pandas as pd
# ----> 2 from keras.models import Sequential
#       3 from keras.layers import Dense
#
# C:\My_programs_2\Anaconda\lib\site-packages\keras\__init__.py in <module>
#       3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
# ----> 5     raise ImportError(
#       6         'Keras requires TensorFlow 2.2 or higher. '
#       7         'Install TensorFlow via `pip install tensorflow`')
#
# ImportError: Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`

# %%
df=pd.DataFrame(pd.read_csv("Cleaned.csv",low_memory=False))
df.drop("Unnamed: 0",axis=1,inplace=True)
df
# Out:
#       venue  inning  Date  bat_team  bowl_team  \
# 0        15       1  2008         7         13
# 1        15       2  2008        13          7
# 2        27       1  2008         0          5
# 3        27       2  2008         5          0
# 4         9       1  2008        10          3
# ...     ...     ...   ...       ...        ...
# 1628     19       1  2021         8         13
# 1629     19       2  2021        13          8
# 1630     41       1  2021         0          2
# 1631     41       2  2021         2          0
# 1632     19       1  2021         7         14
#
#                                                 batsmen  \
# 0     ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...
# 1     ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 2     ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...
# 3     ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 4     ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...
# ...                                                 ...
# 1628  ['RG Sharma', 'CA Lynn', 'SA Yadav', 'Ishan Ki...
# 1629  ['Washington Sundar', 'V Kohli', 'RM Patidar',...
# 1630  ['RD Gaikwad', 'F du Plessis', 'MM Ali', 'SK R...
# 1631   ['PP Shaw', 'S Dhawan', 'RR Pant', 'MP Stoinis']
# 1632  ['N Rana', 'Shubman Gill', 'RA Tripathi', 'AD ...
#
#                                                 bowlers   run  batsman1  \
# 0     ['P Kumar', 'Z Khan', 'AA Noffke', 'JH Kallis'...  71.0       116
# 1     ['AB Dinda', 'I Sharma', 'AB Agarkar', 'SC Gan...  33.0        93
# 2     ['B Lee', 'S Sreesanth', 'JR Hopes', 'IK Patha...  56.0        87
# 3     ['JDP Oram', 'MS Gony', 'M Muralitharan', 'P A...  65.0        53
# 4     ['GD McGrath', 'B Geeves', 'MF Maharoof', 'R B...  42.0       129
# ...                                                 ...   ...       ...
# 1628  ['Mohammed Siraj', 'KA Jamieson', 'YS Chahal',...  41.0        99
# 1629  ['TA Boult', 'JJ Bumrah', 'M Jansen', 'KH Pand...  54.0       139
# 1630  ['CR Woakes', 'Avesh Khan', 'R Ashwin', 'TK Cu...  36.0        97
# 1631  ['DL Chahar', 'SM Curran', 'SN Thakur', 'RA Ja...  65.0        91
# 1632  ['B Kumar', 'Sandeep Sharma', 'T Natarajan', '...  50.0        80
#
#       batsman2  bowler1  bowler2
# 0           14      124      219
# 1          145       11       77
# 2           82       28      178
# 3           57       75      133
# 4          149       57       31
# ...        ...      ...      ...
# 1628        19      116      103
# 1629       141      178       90
# 1630        34       42       29
# 1631       113       48      185
# 1632       135       27      194
#
# [1633 rows x 12 columns]

# %%
X = df.iloc[:,[0,1,2,3,4]]
y = df.iloc[:,[7]]

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6a9867103bba> in <module>
# ----> 1 model = Sequential()
#       2 model.add(Dense(12, input_dim=8, activation='relu'))
#       3 model.add(Dense(8, activation='relu'))
#       4 model.add(Dense(1, activation='sigmoid'))
#
# NameError: name 'Sequential' is not defined
